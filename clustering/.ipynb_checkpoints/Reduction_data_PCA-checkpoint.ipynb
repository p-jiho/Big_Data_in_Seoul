# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from functools import reduce
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import SilhouetteVisualizer

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN
from minisom import MiniSom

# %% [markdown]
# # 데이터 정리

# %%
T_df = pd.read_csv("../data/Total_data_29col.csv", index_col=0)

# %%
T_df.corr().loc[T_df.columns, T_df.columns].style.background_gradient()
# Out:
# <style type="text/css">
# #T_9b8db_row0_col0, #T_9b8db_row1_col1, #T_9b8db_row2_col2, #T_9b8db_row3_col3, #T_9b8db_row4_col4, #T_9b8db_row5_col5, #T_9b8db_row6_col6, #T_9b8db_row7_col7, #T_9b8db_row8_col8, #T_9b8db_row9_col9, #T_9b8db_row10_col10, #T_9b8db_row11_col11, #T_9b8db_row12_col12, #T_9b8db_row12_col13, #T_9b8db_row13_col12, #T_9b8db_row13_col13, #T_9b8db_row14_col14, #T_9b8db_row15_col15, #T_9b8db_row16_col16, #T_9b8db_row17_col17, #T_9b8db_row17_col18, #T_9b8db_row17_col19, #T_9b8db_row17_col20, #T_9b8db_row17_col21, #T_9b8db_row17_col22, #T_9b8db_row17_col23, #T_9b8db_row17_col24, #T_9b8db_row17_col25, #T_9b8db_row17_col26, #T_9b8db_row17_col27, #T_9b8db_row17_col28, #T_9b8db_row18_col17, #T_9b8db_row18_col18, #T_9b8db_row18_col19, #T_9b8db_row18_col20, #T_9b8db_row18_col21, #T_9b8db_row18_col22, #T_9b8db_row18_col23, #T_9b8db_row18_col24, #T_9b8db_row18_col25, #T_9b8db_row18_col26, #T_9b8db_row18_col27, #T_9b8db_row18_col28, #T_9b8db_row19_col17, #T_9b8db_row19_col18, #T_9b8db_row19_col19, #T_9b8db_row19_col20, #T_9b8db_row19_col21, #T_9b8db_row19_col22, #T_9b8db_row19_col23, #T_9b8db_row19_col24, #T_9b8db_row19_col25, #T_9b8db_row19_col26, #T_9b8db_row19_col27, #T_9b8db_row19_col28, #T_9b8db_row20_col17, #T_9b8db_row20_col18, #T_9b8db_row20_col19, #T_9b8db_row20_col20, #T_9b8db_row20_col21, #T_9b8db_row20_col22, #T_9b8db_row20_col23, #T_9b8db_row20_col24, #T_9b8db_row20_col25, #T_9b8db_row20_col26, #T_9b8db_row20_col27, #T_9b8db_row20_col28, #T_9b8db_row21_col17, #T_9b8db_row21_col18, #T_9b8db_row21_col19, #T_9b8db_row21_col20, #T_9b8db_row21_col21, #T_9b8db_row21_col22, #T_9b8db_row21_col23, #T_9b8db_row21_col24, #T_9b8db_row21_col25, #T_9b8db_row21_col26, #T_9b8db_row21_col27, #T_9b8db_row21_col28, #T_9b8db_row22_col17, #T_9b8db_row22_col18, #T_9b8db_row22_col19, #T_9b8db_row22_col20, #T_9b8db_row22_col21, #T_9b8db_row22_col22, #T_9b8db_row22_col23, #T_9b8db_row22_col24, #T_9b8db_row22_col25, #T_9b8db_row22_col26, #T_9b8db_row22_col27, #T_9b8db_row22_col28, #T_9b8db_row23_col17, #T_9b8db_row23_col18, #T_9b8db_row23_col19, #T_9b8
col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_9b8db_row0_col11, #T_9b8db_row5_col15, #T_9b8db_row6_col13, #T_9b8db_row9_col3, #T_9b8db_row10_col12, #T_9b8db_row16_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_9b8db_row0_col12, #T_9b8db_row6_col15 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_9b8db_row0_col13, #T_9b8db_row1_col13, #T_9b8db_row2_col9 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_9b8db_row0_col14, #T_9b8db_row15_col19, #T_9b8db_row15_col28, #T_9b8db_row21_col5 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_9b8db_row0_col15, #T_9b8db_row1_col7, #T_9b8db_row6_col1, #T_9b8db_row9_col15, #T_9b8db_row16_col5, #T_9b8db_row16_col12 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_9b8db_row0_col16, #T_9b8db_row5_col18, #T_9b8db_row5_col20, #T_9b8db_row5_col24, #T_9b8db_row5_col25, #T_9b8db_row5_col27, #T_9b8db_row6_col4 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_9b8db_row0_col17, #T_9b8db_row0_col18, #T_9b8db_row0_col20, #T_9b8db_row0_col27, #T_9b8db_row11_col2 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_9b8db_row0_col19, #T_9b8db_row0_col23, #T_9b8db_row2_col11 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_9b8db_row0_col21, #T_9b8db_row0_col22 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_9b8db_row0_col24, #T_9b8db_row0_col26, #T_9b8db_row0_col28 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_9b8db_row0_col25 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_9b8db_row1_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_9b8db_row1_col3, #T_9b8db_row14_col17, #T_9b8db_row14_col24, #T_9b8db_row14_col28, #T_9b8db_row17_col14, #T_9b8db_row28_col14 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_9b8db_row1_col4 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_9b8db_row1_col5 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_9b8db_row1_col6, #T_9b8db_row1_col20, #T_9b8db_row1_col21, #T_9b8db_row1_col22, #T_9b8db_row1_col26, #T_9b8db_row1_col27, #T_9b8db_row4_col19, #T_9b8db_row4_col22 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_9b8db_row1_col8, #T_9b8db_row19_col1, #T_9b8db_row21_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_9b8db_row1_col9, #T_9b8db_row4_col11, #T_9b8db_row6_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_9b8db_row1_col10, #T_9b8db_row2_col10, #T_9b8db_row6_col17, #T_9b8db_row6_col23, #T_9b8db_row11_col16, #T_9b8db_row15_col4, #T_9b8db_row16_col14, #T_9b8db_row22_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_9b8db_row1_col11, #T_9b8db_row1_col12, #T_9b8db_row1_col19, #T_9b8db_row1_col28, #T_9b8db_row3_col11, #T_9b8db_row4_col21, #T_9b8db_row6_col11, #T_9b8db_row16_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_9b8db_row1_col14 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_9b8db_row1_col15, #T_9b8db_row15_col0, #T_9b8db_row15_col12 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9b8db_row1_col16, #T_9b8db_row15_col11 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_9b8db_row1_col17, #T_9b8db_row

# %%
Scaler = MinMaxScaler()
Data_Scale = Scaler.fit_transform(T_df)
pca = PCA(n_components = 2)
pca.fit(Data_Scale)
DS = pd.DataFrame(pca.transform(Data_Scale))
DS.columns = ["PCA1", "PCA2"]

# %%
# 혼잡도 데이터는 상관계수가 매우 높아서 max로 통합
Congestion = T_df[['time5_9', 'time9_12', 'time12_15', 'time15_18', 'time18_21','time21_24']]
Congestion = pd.DataFrame(Congestion.max(axis='columns'))
Congestion.columns = ["Congestion"]
Congestion = Congestion.reset_index()

# 역 면적은 상관계수가 높지 않음
Subway_Area = T_df[['역면적']]
Subway_Area.columns = ["Subway_Area"]
Subway_Area = Subway_Area.reset_index()

# 엘리베이터 관련 데이터는 상관계수가 매우 높아서 총 개수만 사용
Elevator = T_df[['엘리베이터총개수']]
Elevator.columns = ["Elevator"]
Elevator = Elevator.reset_index()

# 정주인구 데이터도 상관계수가 높아서 인구만 사용
Population = T_df[['인구']]
Population.columns = ["Population"]
Population = Population.reset_index()

# 공실 데이터도 공실면적만 사용
Lease = T_df[["공실면적"]]
Lease.columns = ["Lease"]
Lease = Lease.reset_index()

# 택배데이터는 1년 평균을 사용
Parcel = T_df[['택배_2308','택배_2307', '택배_2306', '택배_2305', '택배_2304', '택배_2303', '택배_2302',
               '택배_2301', '택배_2212', '택배_2211', '택배_2210', '택배_2209']]
Parcel = pd.DataFrame(Parcel.max(axis='columns'))
Parcel.columns = ["Parcel"]
Parcel = Parcel.reset_index()

# %%
T_df = reduce(lambda x,y: pd.merge(x,y, on='역명', how='inner'), [Congestion, Subway_Area, Elevator, Population, Lease, Parcel])
T_df.index = T_df.역명
T_df = T_df.loc[:, ~T_df.columns.isin(["역명"])]

# %% [markdown]
# # 클러스터 갯수 선정
# - Elbow : 4개를 최적으로 추천
# - Silhouette : 2개기 최적으로 보임
#
# ### => 4개, 2개를 각각 실행 후 비교

# %% [markdown]
# ### Elbow

# %%
KMeans_Model = KMeans(init='k-means++', random_state = 1234)
visualizer = KElbowVisualizer(KMeans_Model, k=(1,10))
visualizer.fit(DS)
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=9, random_state=1234),
#                  k=(1, 10))

# %% [markdown]
# ### 2. Silhouette

# %%
#클러스터링 모델 생성
KMeans_2 = KMeans(n_clusters=2, init='k-means++', random_state = 1234)
#visualizer 생성
visualizer_2 = SilhouetteVisualizer(KMeans_2, colors='yellowbrick')
#생성된 visualizer에 데이터 입력 
visualizer_2.fit(DS)      
visualizer_2.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 17 Samples in 2 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
#클러스터링 모델 생성
KMeans_3 = KMeans(n_clusters=3, init='k-means++', random_state = 1234)
#visualizer 생성
visualizer_3 = SilhouetteVisualizer(KMeans_3, colors='yellowbrick')
#생성된 visualizer에 데이터 입력 
visualizer_3.fit(DS)      
visualizer_3.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 17 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
#클러스터링 모델 생성
KMeans_4 = KMeans(n_clusters=4,init='k-means++', random_state = 1234)
#visualizer 생성
visualizer_4 = SilhouetteVisualizer(KMeans_4, colors='yellowbrick')
#생성된 visualizer에 데이터 입력 
visualizer_4.fit(DS)      
visualizer_4.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 17 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# # 모델링

# %% [markdown]
# ### 1. K = 2

# %% [markdown]
# ### - K-means

# %%
k = 2
KMeans_Model = KMeans(n_clusters = k,init='k-means++', random_state = 1234)

# 정규화된 데이터에 학습
KMeans_Model.fit(DS)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
T_KMeans = T_df.copy()
T_KMeans['cluster'] = KMeans_Model.fit_predict(DS)
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# - cluster 0 : 혼잡도 - 고루 분포, 엘리베이터 - 10 이하, 인구 - 많은 편, 택배 - 많은 편
# - cluster 1 : 혼잡도 - 중간쯤 분포, 엘리베이터 - 9 이상, 인구 - 적은 편, 택배 - 적은 편

# %%
sns.pairplot(T_KMeans, hue="cluster")
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### GMM

# %%
GMM = GaussianMixture(n_components=2, random_state = 1234)
GMM.fit(DS)
cluster = GMM.predict(DS)
Total_GMM = T_df.copy()
Total_GMM['cluster'] = cluster
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
sns.pairplot(Total_GMM, hue="cluster")
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### DBSCAN

# %%
DBSCAN_Model = DBSCAN(eps=0.5,min_samples=2)
cluster = DBSCAN_Model.fit_predict(DS)
Total_DBSCAN = T_df.copy()
Total_DBSCAN['cluster'] = cluster

# %%
palette = sns.color_palette("deep", 3)
sns.pairplot(Total_DBSCAN, hue="cluster", palette = palette)
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### SOM

# %%
SOM = MiniSom(x = 2, y = 1, input_len = 2)
SOM.random_weights_init(DS.values)
SOM.train(DS.values, 100)

# %%
Win = np.array([SOM.winner(x) for x in DS.values]).T
Total_SOM = T_df.copy()
Total_SOM['cluster'] = np.ravel_multi_index(Win,(2,2))

# %%
sns.pairplot(Total_SOM, hue="cluster")
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 2. K = 4

# %% [markdown]
# ### - KMeans

# %%
k = 4
KMeans_Model_4 = KMeans(n_clusters = k,init='k-means++', random_state = 1234)

# 정규화된 데이터에 학습
KMeans_Model_4.fit(DS)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
T_KMeans_4 = T_df.copy()
T_KMeans_4['cluster'] = KMeans_Model_4.fit_predict(DS)
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
palette = sns.color_palette("deep", 4)
sns.pairplot(T_KMeans_4, hue="cluster", palette = palette)
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### - GMM

# %%
GMM_4 = GaussianMixture(n_components=4, random_state = 1234)
GMM_4.fit(DS)
cluster = GMM_4.predict(DS)
Total_GMM_4 = T_df.copy()
Total_GMM_4['cluster'] = cluster
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
palette = sns.color_palette("deep", 4)
sns.pairplot(Total_GMM_4, hue="cluster", palette = palette)
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### - DBSCAN

# %%
DBSCAN_Model = DBSCAN(eps=0.4,min_samples=2)
cluster = DBSCAN_Model.fit_predict(DS)
Total_DBSCAN_4 = T_df.copy()
Total_DBSCAN_4['cluster'] = cluster

# %%
palette = sns.color_palette("deep", 5)
sns.pairplot(Total_DBSCAN_4, hue="cluster", palette = palette)
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### - SOM

# %%
SOM_4 = MiniSom(x = 2, y = 2, input_len = 2)
SOM_4.random_weights_init(DS.values)
SOM_4.train(DS.values, 100)

# %%
Win = np.array([SOM_4.winner(x) for x in DS.values]).T
Total_SOM_4 = T_df.copy()
Total_SOM_4['cluster'] = np.ravel_multi_index(Win,(2,2))

# %%
palette = sns.color_palette("deep", 4)
sns.pairplot(Total_SOM_4, hue="cluster", palette = palette)
plt.show()
# Out:
# C:\Users\Ryzen\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
